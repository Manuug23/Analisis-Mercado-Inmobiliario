# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %config IPCompleter.greedy = True

# %%
listings = pd.read_csv('../Datos/listings.csv')
listings
# Out:
#              id                                               name    host_id  \
# 0          6369           Rooftop terrace room ,  ensuite bathroom      13660
# 1         21853                               Bright and airy room      83531
# 2         23001                  Apartmento Arganzuela- Madrid Rio      82175
# 3         24805                             Gran Via Studio Madrid  346366726
# 4         26825                 Single Room whith private Bathroom     114340
# ...         ...                                                ...        ...
# 18904  52182264  Enormous Private Room in 12-Bedroom Unit - los...  378060726
# 18905  52182273  Stunning Private Room in 11-Bedroom Unit - los...  378060726
# 18906  52182303  Classic Private Room in 7-Bedroom Unit - los 3...  378060726
# 18907  52182321  Elegant Private Room in 12-Bedroom Unit - los ...  378060726
# 18908  52182334  Fashioned Private Room in 12-Bedroom Unit - lo...  378060726
#
#       host_name neighbourhood_group   neighbourhood   latitude  longitude  \
# 0         Simon           Chamartín  Hispanoamérica  40.457240  -3.676880
# 1         Abdel              Latina        Cármenes  40.403810  -3.741300
# 2         Jesus          Arganzuela         Legazpi  40.388400  -3.695110
# 3             A              Centro     Universidad  40.421830  -3.705290
# 4      Agustina          Arganzuela         Legazpi  40.389750  -3.690180
# ...         ...                 ...             ...        ...        ...
# 18904  Svetlana              Centro        Justicia  40.424384  -3.691216
# 18905  Svetlana              Centro        Justicia  40.424447  -3.691309
# 18906  Svetlana              Centro        Justicia  40.424989  -3.691783
# 18907  Svetlana           Salamanca       Recoletos  40.424352  -3.690211
# 18908  Svetlana              Centro        Justicia  40.425670  -3.691727
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room     60               1                 80  2019-05-14
# 1         Private room     31               4                 33  2018-05-29
# 2      Entire home/apt     50              15                  0         NaN
# 3      Entire home/apt     92               5                 12  2020-03-01
# 4         Private room     26               2                149  2018-05-15
# ...                ...    ...             ...                ...         ...
# 18904     Private room     29               1                  0         NaN
# 18905     Private room     29               1                  0         NaN
# 18906     Private room     29               1                  0         NaN
# 18907     Private room     29               1                  0         NaN
# 18908     Private room     33               1                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   1.21                               2               180
# 1                   0.39                               2               364
# 2                    NaN                               5               222
# 3                   0.51                               1               115
# 4                   1.65                               1               349
# ...                  ...                             ...               ...
# 18904                NaN                              87               358
# 18905                NaN                              87               358
# 18906                NaN                              87               358
# 18907                NaN                              87               358
# 18908                NaN                              87               358
#
#        number_of_reviews_ltm license
# 0                          4     NaN
# 1                          0     NaN
# 2                          0     NaN
# 3                          2     NaN
# 4                          0     NaN
# ...                      ...     ...
# 18904                      0     NaN
# 18905                      0     NaN
# 18906                      0     NaN
# 18907                      0     NaN
# 18908                      0     NaN
#
# [18909 rows x 18 columns]

# %%
listings.head()
# Out:
#       id                                      name    host_id host_name  \
# 0   6369  Rooftop terrace room ,  ensuite bathroom      13660     Simon
# 1  21853                      Bright and airy room      83531     Abdel
# 2  23001         Apartmento Arganzuela- Madrid Rio      82175     Jesus
# 3  24805                    Gran Via Studio Madrid  346366726         A
# 4  26825        Single Room whith private Bathroom     114340  Agustina
#
#   neighbourhood_group   neighbourhood  latitude  longitude        room_type  \
# 0           Chamartín  Hispanoamérica  40.45724   -3.67688     Private room
# 1              Latina        Cármenes  40.40381   -3.74130     Private room
# 2          Arganzuela         Legazpi  40.38840   -3.69511  Entire home/apt
# 3              Centro     Universidad  40.42183   -3.70529  Entire home/apt
# 4          Arganzuela         Legazpi  40.38975   -3.69018     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0     60               1                 80  2019-05-14               1.21
# 1     31               4                 33  2018-05-29               0.39
# 2     50              15                  0         NaN                NaN
# 3     92               5                 12  2020-03-01               0.51
# 4     26               2                149  2018-05-15               1.65
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                               2               180                      4
# 1                               2               364                      0
# 2                               5               222                      0
# 3                               1               115                      2
# 4                               1               349                      0
#
#   license
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18909 entries, 0 to 18908
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              18909 non-null  int64
#  1   name                            18906 non-null  object
#  2   host_id                         18909 non-null  int64
#  3   host_name                       18883 non-null  object
#  4   neighbourhood_group             18909 non-null  object
#  5   neighbourhood                   18909 non-null  object
#  6   latitude                        18909 non-null  float64
#  7   longitude                       18909 non-null  float64
#  8   room_type                       18909 non-null  object
#  9   price                           18909 non-null  int64
#  10  minimum_nights                  18909 non-null  int64
#  11  number_of_reviews               18909 non-null  int64
#  12  last_review                     13877 non-null  object
#  13  reviews_per_month               13877 non-null  float64
#  14  calculated_host_listings_count  18909 non-null  int64
#  15  availability_365                18909 non-null  int64
#  16  number_of_reviews_ltm           18909 non-null  int64
#  17  license                         2828 non-null   object
# dtypes: float64(3), int64(8), object(7)
# memory usage: 2.6+ MB

# %%
listings_det = pd.read_csv('../Datos/listings.csv.gz',compression='gzip')
listings_det
# Out:
#              id                            listing_url       scrape_id  \
# 0          6369      https://www.airbnb.com/rooms/6369  20210910193531
# 1         21853     https://www.airbnb.com/rooms/21853  20210910193531
# 2         23001     https://www.airbnb.com/rooms/23001  20210910193531
# 3         24805     https://www.airbnb.com/rooms/24805  20210910193531
# 4         26825     https://www.airbnb.com/rooms/26825  20210910193531
# ...         ...                                    ...             ...
# 18904  52182264  https://www.airbnb.com/rooms/52182264  20210910193531
# 18905  52182273  https://www.airbnb.com/rooms/52182273  20210910193531
# 18906  52182303  https://www.airbnb.com/rooms/52182303  20210910193531
# 18907  52182321  https://www.airbnb.com/rooms/52182321  20210910193531
# 18908  52182334  https://www.airbnb.com/rooms/52182334  20210910193531
#
#       last_scraped                                               name  \
# 0       2021-09-11           Rooftop terrace room ,  ensuite bathroom
# 1       2021-09-11                               Bright and airy room
# 2       2021-09-11                  Apartmento Arganzuela- Madrid Rio
# 3       2021-09-11                             Gran Via Studio Madrid
# 4       2021-09-11                 Single Room whith private Bathroom
# ...            ...                                                ...
# 18904   2021-09-11  Enormous Private Room in 12-Bedroom Unit - los...
# 18905   2021-09-11  Stunning Private Room in 11-Bedroom Unit - los...
# 18906   2021-09-11  Classic Private Room in 7-Bedroom Unit - los 3...
# 18907   2021-09-11  Elegant Private Room in 12-Bedroom Unit - los ...
# 18908   2021-09-11  Fashioned Private Room in 12-Bedroom Unit - lo...
#
#                                              description  \
# 0      Excellent connection with the AIRPORT and EXHI...
# 1      We have a quiet and sunny room with a good vie...
# 2      Apartamento de tres dormitorios dobles, gran s...
# 3      Studio located 50 meters from Gran Via, next t...
# 4      Nice and cozy roon for one person with a priva...
# ...                                                  ...
# 18904  ROOM - 8 sqm. • 1st Floor <br /> <br />cozy ro...
# 18905  ROOM - 10 sqm. • 4th Floor <br /> <br />cozy r...
# 18906  ROOM <br /> <br />cozy room in madrid centro i...
# 18907  ROOM -9 sqm. • 1st Floor <br /> <br />cozy roo...
# 18908  ROOM - 10 sqm. • 1st Floor <br /> <br />cozy r...
#
#                                    neighborhood_overview  \
# 0                                                    NaN
# 1      We live in a leafy neighbourhood with plenty o...
# 2      Barrio Arganzuela, junto a Madrid Rio, zonas c...
# 3      The area is next to the Gran Via, so people li...
# 4      Es un barrio muy tranquilo, en una zona de Mad...
# ...                                                  ...
# 18904                                                NaN
# 18905                                                NaN
# 18906                                                NaN
# 18907                                                NaN
# 18908                                                NaN
#
#                                              picture_url    host_id  \
# 0      https://a0.muscache.com/pictures/683224/4cc318...      13660
# 1      https://a0.muscache.com/pictures/68483181/87bc...      83531
# 2      https://a0.muscache.com/pictures/58e6a770-509c...      82175
# 3      https://a0.muscache.com/pictures/miso/Hosting-...  346366726
# 4      https://a0.muscache.com/pictures/149358/218d5b...     114340
# ...                                                  ...        ...
# 18904  https://a0.muscache.com/pictures/prohost-api/H...  378060726
# 18905  https://a0.muscache.com/pictures/prohost-api/H...  378060726
# 18906  https://a0.muscache.com/pictures/prohost-api/H...  378060726
# 18907  https://a0.muscache.com/pictures/prohost-api/H...  378060726
# 18908  https://a0.muscache.com/pictures/prohost-api/H...  378060726
#
#                                           host_url  ...  \
# 0          https://www.airbnb.com/users/show/13660  ...
# 1          https://www.airbnb.com/users/show/83531  ...
# 2          https://www.airbnb.com/users/show/82175  ...
# 3      https://www.airbnb.com/users/show/346366726  ...
# 4         https://www.airbnb.com/users/show/114340  ...
# ...                                            ...  ...
# 18904  https://www.airbnb.com/users/show/378060726  ...
# 18905  https://www.airbnb.com/users/show/378060726  ...
# 18906  https://www.airbnb.com/users/show/378060726  ...
# 18907  https://www.airbnb.com/users/show/378060726  ...
# 18908  https://www.airbnb.com/users/show/378060726  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            4.89                   4.77                4.85
# 1                            4.82                   4.21                4.67
# 2                             NaN                    NaN                 NaN
# 3                            5.00                   5.00                4.83
# 4                            4.71                   4.70                4.72
# ...                           ...                    ...                 ...
# 18904                         NaN                    NaN                 NaN
# 18905                         NaN                    NaN                 NaN
# 18906                         NaN                    NaN                 NaN
# 18907                         NaN                    NaN                 NaN
# 18908                         NaN                    NaN                 NaN
#
#       license instant_bookable calculated_host_listings_count  \
# 0         NaN                f                              2
# 1         NaN                f                              2
# 2         NaN                f                              5
# 3         NaN                f                              1
# 4         NaN                f                              1
# ...       ...              ...                            ...
# 18904     NaN                f                             87
# 18905     NaN                f                             87
# 18906     NaN                f                             87
# 18907     NaN                f                             87
# 18908     NaN                f                             87
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               0
# 1                                               0
# 2                                               4
# 3                                               1
# 4                                               0
# ...                                           ...
# 18904                                           0
# 18905                                           0
# 18906                                           0
# 18907                                           0
# 18908                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                2
# 1                                                2
# 2                                                1
# 3                                                0
# 4                                                1
# ...                                            ...
# 18904                                           87
# 18905                                           87
# 18906                                           87
# 18907                                           87
# 18908                                           87
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                               0              1.21
# 1                                               0              0.39
# 2                                               0               NaN
# 3                                               0              0.51
# 4                                               0              1.65
# ...                                           ...               ...
# 18904                                           0               NaN
# 18905                                           0               NaN
# 18906                                           0               NaN
# 18907                                           0               NaN
# 18908                                           0               NaN
#
# [18909 rows x 74 columns]

# %%
reviews = pd.read_csv('../Datos/reviews.csv')
reviews
# Out:
#         listing_id        date
# 0             6369  2010-03-14
# 1             6369  2010-03-23
# 2             6369  2010-04-10
# 3             6369  2010-04-21
# 4             6369  2010-04-26
# ...            ...         ...
# 618435    51973214  2021-09-08
# 618436    51980116  2021-09-10
# 618437    52008642  2021-09-07
# 618438    52052285  2021-09-10
# 618439    52108468  2021-09-09
#
# [618440 rows x 2 columns]

# %%
reviews.head()
# Out:
#    listing_id        date
# 0        6369  2010-03-14
# 1        6369  2010-03-23
# 2        6369  2010-04-10
# 3        6369  2010-04-21
# 4        6369  2010-04-26

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 618440 entries, 0 to 618439
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   listing_id  618440 non-null  int64
#  1   date        618440 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 9.4+ MB

# %%
reviews_det = pd.read_csv('../Datos/reviews.csv.gz')
reviews_det
# Out:
#         listing_id                  id        date  reviewer_id reviewer_name  \
# 0             6369               29428  2010-03-14        84790         Nancy
# 1             6369               31018  2010-03-23        84338         David
# 2             6369               34694  2010-04-10        98655        Marion
# 3             6369               37146  2010-04-21       109871          Kurt
# 4             6369               38168  2010-04-26        98901        Dennis
# ...            ...                 ...         ...          ...           ...
# 618435    51973214  446889303676978437  2021-09-08     84766723        Carlos
# 618436    51980116  448262265778800520  2021-09-10    402075230       Whitney
# 618437    52008642  446104706506667601  2021-09-07    221711995         Laila
# 618438    52052285  448277529746454343  2021-09-10     80169124           Ana
# 618439    52108468  447559235257304311  2021-09-09     32953673   María Jesús
#
#                                                  comments
# 0       Simon and Arturo have the ultimate location in...
# 1       Myself and Kristy originally planned on stayin...
# 2       We had a great time at Arturo and Simon's ! A ...
# 3       I very much enjoyed the stay.  \r<br/>It's a w...
# 4       Arturo and Simon are polite and friendly hosts...
# ...                                                   ...
# 618435  The location of this apartment is unbeatable, ...
# 618436  Daniela es un amor. Atenta, amable y buena con...
# 618437  El apartamento está bien ubicado, bonito y lim...
# 618438  Miguel es un hombre encantador, la habitación ...
# 618439  Maria´s apartment is stylish and absolutely st...
#
# [618440 rows x 6 columns]

# %%
calendar = pd.read_csv('../Datos/calendar.csv.gz')
calendar
# Out:
#          listing_id        date available    price adjusted_price  \
# 0              6369  2021-09-11         t   $60.00         $60.00
# 1              6369  2021-09-12         t   $60.00         $60.00
# 2              6369  2021-09-13         t   $60.00         $60.00
# 3              6369  2021-09-14         t   $60.00         $60.00
# 4              6369  2021-09-15         t   $60.00         $60.00
# ...             ...         ...       ...      ...            ...
# 6901409    52099549  2022-09-06         f  $493.00        $493.00
# 6901410    52099549  2022-09-07         f  $493.00        $493.00
# 6901411    52099549  2022-09-08         f  $493.00        $493.00
# 6901412    52099549  2022-09-09         f  $493.00        $493.00
# 6901413    52099549  2022-09-10         f  $493.00        $493.00
#
#          minimum_nights  maximum_nights
# 0                   1.0          1125.0
# 1                   1.0          1125.0
# 2                   1.0          1125.0
# 3                   1.0          1125.0
# 4                   1.0          1125.0
# ...                 ...             ...
# 6901409            14.0          1125.0
# 6901410            14.0          1125.0
# 6901411            14.0          1125.0
# 6901412            14.0          1125.0
# 6901413            14.0          1125.0
#
# [6901414 rows x 7 columns]

# %%
calendar.head()
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0        6369  2021-09-11         t  $60.00         $60.00             1.0
# 1        6369  2021-09-12         t  $60.00         $60.00             1.0
# 2        6369  2021-09-13         t  $60.00         $60.00             1.0
# 3        6369  2021-09-14         t  $60.00         $60.00             1.0
# 4        6369  2021-09-15         t  $60.00         $60.00             1.0
#
#    maximum_nights
# 0          1125.0
# 1          1125.0
# 2          1125.0
# 3          1125.0
# 4          1125.0

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6901414 entries, 0 to 6901413
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  float64
#  6   maximum_nights  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 368.6+ MB

# %%
calendar.date.min()
# Out:
# '2021-09-10'

# %%
pd.read_csv('../Datos/neighbourhoods.csv')
# Out:
#     neighbourhood_group  neighbourhood
# 0            Arganzuela        Acacias
# 1            Arganzuela         Atocha
# 2            Arganzuela        Chopera
# 3            Arganzuela       Delicias
# 4            Arganzuela       Imperial
# ..                  ...            ...
# 123          Villaverde       Butarque
# 124          Villaverde    Los Angeles
# 125          Villaverde    Los Rosales
# 126          Villaverde     San Andrés
# 127          Villaverde  San Cristobal
#
# [128 rows x 2 columns]

# %%
pd.read_json('../Datos/neighbourhoods.geojson')
# Out:
#                   type                                           features
# 0    FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 1    FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 2    FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 3    FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 4    FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# ..                 ...                                                ...
# 123  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 124  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 125  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 126  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 127  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
#
# [128 rows x 2 columns]

# %%
import sqlalchemy as sa

con = sa.create_engine('sqlite:///../Datos/airbnb.db')

# %%
listings.to_sql('listings', con = con, if_exists='replace')
listings_det.to_sql('listings_det', con = con, if_exists = 'replace')
# Out:
# 18909

# %%
# Out:
#   Cell In[20], line 1
#     jupyter nbextension enable varInspector/main
#             ^
# SyntaxError: invalid syntax
